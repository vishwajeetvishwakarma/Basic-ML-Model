# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression , Ridge , Lasso , LassoCV , RidgeCV , ElasticNet , ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
data = pd.read_csv("Admission_Prediction.csv")

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3        NaN        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84
#
# [500 rows x 9 columns]

# %%
from pandas_profiling import *

# %%
data_pp = ProfileReport(data)

# %%
data_pp.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
data_pp.to_file("report_1.html")
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
data['GRE Score'].fillna(np.mean(data['GRE Score']) , inplace=True)
data
# Out:
#      Serial No.   GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1  337.000000        118.0                4.0  4.5  4.5  9.65
# 1             2  324.000000        107.0                4.0  4.0  4.5  8.87
# 2             3  316.558763        104.0                3.0  3.0  3.5  8.00
# 3             4  322.000000        110.0                3.0  3.5  2.5  8.67
# 4             5  314.000000        103.0                2.0  2.0  3.0  8.21
# ..          ...         ...          ...                ...  ...  ...   ...
# 495         496  332.000000        108.0                5.0  4.5  4.0  9.02
# 496         497  337.000000        117.0                5.0  5.0  5.0  9.87
# 497         498  330.000000        120.0                5.0  4.5  5.0  9.56
# 498         499  312.000000        103.0                4.0  4.0  5.0  8.43
# 499         500  327.000000        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84
#
# [500 rows x 9 columns]

# %%
data['TOEFL Score'].fillna(np.mean(data['TOEFL Score']) , inplace=True)
data['University Rating'].fillna(np.mean(data['University Rating']) , inplace=True)
data
# Out:
#      Serial No.   GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1  337.000000        118.0                4.0  4.5  4.5  9.65
# 1             2  324.000000        107.0                4.0  4.0  4.5  8.87
# 2             3  316.558763        104.0                3.0  3.0  3.5  8.00
# 3             4  322.000000        110.0                3.0  3.5  2.5  8.67
# 4             5  314.000000        103.0                2.0  2.0  3.0  8.21
# ..          ...         ...          ...                ...  ...  ...   ...
# 495         496  332.000000        108.0                5.0  4.5  4.0  9.02
# 496         497  337.000000        117.0                5.0  5.0  5.0  9.87
# 497         498  330.000000        120.0                5.0  4.5  5.0  9.56
# 498         499  312.000000        103.0                4.0  4.0  5.0  8.43
# 499         500  327.000000        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.76
# 2           1             0.72
# 3           1             0.80
# 4           0             0.65
# ..        ...              ...
# 495         1             0.87
# 496         1             0.96
# 497         1             0.93
# 498         0             0.73
# 499         0             0.84
#
# [500 rows x 9 columns]

# %%
data.drop(columns=['Serial No.'] , inplace=True)

# %%
data
# Out:
#       GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# 3               0.80
# 4               0.65
# ..               ...
# 495             0.87
# 496             0.96
# 497             0.93
# 498             0.73
# 499             0.84
#
# [500 rows x 8 columns]

# %%
y = data['Chance of Admit']
x = data.drop(columns=['Chance of Admit'])

# %%
x
# Out:
#       GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 500, dtype: float64

# %%
x.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research'],
#       dtype='object')

# %%
scalar = StandardScaler()

# %%
new_x_arr = scalar.fit_transform(x)

# %%
new_x_arr
# Out:
# array([[ 1.84274116e+00,  1.78854223e+00,  7.78905651e-01, ...,
#          1.09894429e+00,  1.77680627e+00,  8.86405260e-01],
#        [ 6.70814288e-01, -3.10581135e-02,  7.78905651e-01, ...,
#          1.09894429e+00,  4.85859428e-01,  8.86405260e-01],
#        [ 5.12433309e-15, -5.27312752e-01, -1.07876604e-01, ...,
#          1.73062093e-02, -9.54042814e-01,  8.86405260e-01],
#        ...,
#        [ 1.21170361e+00,  2.11937866e+00,  1.66568791e+00, ...,
#          1.63976333e+00,  1.62785086e+00,  8.86405260e-01],
#        [-4.10964364e-01, -6.92730965e-01,  7.78905651e-01, ...,
#          1.63976333e+00, -2.42366993e-01, -1.12815215e+00],
#        [ 9.41258951e-01,  9.61451165e-01,  7.78905651e-01, ...,
#          1.09894429e+00,  7.67219636e-01, -1.12815215e+00]])

# %%
x_new = pd.DataFrame(new_x_arr , columns=['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
       'Research'])

# %%
x_new
# Out:
#         GRE Score  TOEFL Score  University Rating       SOP       LOR  \
# 0    1.842741e+00     1.788542           0.778906  1.137360  1.098944
# 1    6.708143e-01    -0.031058           0.778906  0.632315  1.098944
# 2    5.124333e-15    -0.527313          -0.107877 -0.377773  0.017306
# 3    4.905178e-01     0.465197          -0.107877  0.127271 -1.064332
# 4   -2.306679e-01    -0.692731          -0.994659 -1.387862 -0.523513
# ..            ...          ...                ...       ...       ...
# 495  1.392000e+00     0.134360           1.665688  1.137360  0.558125
# 496  1.842741e+00     1.623124           1.665688  1.642404  1.639763
# 497  1.211704e+00     2.119379           1.665688  1.137360  1.639763
# 498 -4.109644e-01    -0.692731           0.778906  0.632315  1.639763
# 499  9.412590e-01     0.961451           0.778906  1.137360  1.098944
#
#          CGPA  Research
# 0    1.776806  0.886405
# 1    0.485859  0.886405
# 2   -0.954043  0.886405
# 3    0.154847  0.886405
# 4   -0.606480 -1.128152
# ..        ...       ...
# 495  0.734118  0.886405
# 496  2.140919  0.886405
# 497  1.627851  0.886405
# 498 -0.242367 -1.128152
# 499  0.767220 -1.128152
#
# [500 rows x 7 columns]

# %%
x_new_pp = ProfileReport(x_new)
x_new_pp.to_file("x_new_report1.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_df = pd.DataFrame()
vif_df["feature"] = x.columns

# %%
vif_df['vif_score'] = [variance_inflation_factor(new_x_arr , i) for i in range(new_x_arr.shape[1])]

# %%
vif_df
# Out:
#              feature  vif_score
# 0          GRE Score   4.153268
# 1        TOEFL Score   3.792866
# 2  University Rating   2.508768
# 3                SOP   2.775750
# 4                LOR   2.037308
# 5               CGPA   4.651670
# 6           Research   1.459311

# %%
x_train , x_test , y_train , y_test = train_test_split(x_new, y, test_size=0.25 , random_state=44)

# %%
print("x_train shape" , x_train.shape)
print("x_test shape" , x_test.shape)
print("y_train shape" , y_train.shape)
print("y_test shape" , y_test.shape)
# Out:
# x_train shape (375, 7)
# x_test shape (125, 7)
# y_train shape (375,)
# y_test shape (125,)

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating       SOP       LOR      CGPA  \
# 107   1.932889     1.623124           0.778906  0.127271  1.098944  1.462345
# 424   0.760963     1.126869           1.665688  0.632315  1.639763  1.462345
# 497   1.211704     2.119379           1.665688  1.137360  1.639763  1.627851
# 309  -0.771557     0.000000           0.778906  0.127271 -0.523513  0.038993
# 372   1.752593     1.953960           0.778906  1.137360  0.558125  1.727154
# ..         ...          ...                ...       ...       ...       ...
# 59   -0.501113    -0.527313          -0.994659 -1.387862 -1.605151 -0.457525
# 173   0.580666     0.961451           0.778906  0.632315  1.098944  1.081681
# 241   0.039777    -0.692731          -0.994659 -0.882817 -1.605151 -0.705784
# 419  -0.771557    -0.858149          -0.994659 -1.387862  0.017306 -0.987144
# 276   1.121555     0.961451           1.665688  1.642404  1.098944  1.445794
#
#      Research
# 107  0.886405
# 424  0.886405
# 497  0.886405
# 309 -1.128152
# 372  0.886405
# ..        ...
# 59  -1.128152
# 173  0.886405
# 241 -1.128152
# 419  0.886405
# 276  0.886405
#
# [375 rows x 7 columns]

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[-5.011126e-01,-0.692731,-0.107877,-1.387862,0.558125,-0.805087,-1.128152]])
# Out:
# C:\Users\Vishwajeet\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.62682265])

# %%
x_test
# Out:
#         GRE Score  TOEFL Score  University Rating       SOP       LOR  \
# 91  -1.582891e+00    -1.685240          -0.107877  1.642404  0.017306
# 78  -1.853336e+00    -2.016077          -0.994659 -0.377773 -1.605151
# 471 -5.011126e-01    -0.692731          -0.107877 -1.387862  0.558125
# 304 -3.208161e-01    -0.196476          -0.994659 -0.882817 -1.605151
# 122 -5.912608e-01    -0.196476           0.778906 -1.892906 -1.064332
# ..            ...          ...                ...       ...       ...
# 153  6.708143e-01    -0.361895          -0.107877 -0.377773  0.558125
# 496  1.842741e+00     1.623124           1.665688  1.642404  1.639763
# 124  5.124333e-15    -0.196476           0.778906 -0.882817 -0.523513
# 392  8.511107e-01     0.796033           0.778906  0.632315  0.017306
# 381  2.200732e-01    -0.361895          -0.107877 -0.377773  0.017306
#
#          CGPA  Research
# 91  -1.516763 -1.128152
# 78  -1.715370  0.886405
# 471 -0.805087 -1.128152
# 304 -0.242367 -1.128152
# 122 -0.358221 -1.128152
# ..        ...       ...
# 153  0.287252 -1.128152
# 496  2.140919  0.886405
# 124 -0.176165 -1.128152
# 392  0.899624  0.886405
# 381  0.154847  0.886405
#
# [125 rows x 7 columns]

# %%
y_test
# Out:
# 91     0.38
# 78     0.44
# 471    0.64
# 304    0.62
# 122    0.57
#        ...
# 153    0.79
# 496    0.96
# 124    0.57
# 392    0.84
# 381    0.73
# Name: Chance of Admit, Length: 125, dtype: float64

# %%
y_test.loc[471]
# Out:
# 0.64

# %%
x_test.loc[471]
# Out:
# GRE Score           -0.501113
# TOEFL Score         -0.692731
# University Rating   -0.107877
# SOP                 -1.387862
# LOR                  0.558125
# CGPA                -0.805087
# Research            -1.128152
# Name: 471, dtype: float64

# %%
lr.score(x_test , y_test)
# Out:
# 0.7793710038310874

# %%
def calculate_adjusted_r2(x , y):
    R2 = lr.score(x, y)
    n = x.shape[0]
    k = x.shape[1]
    adjusted_r2 = 1 - ((1 - R2) * (n - 1)) / (n - k - 1)
    return adjusted_r2

# %%
calculate_adjusted_r2(x_test , y_test)
# Out:
# 0.7661709784192721

# %%
lr.coef_
# Out:
# array([0.0179352 , 0.01586169, 0.00790237, 0.00148665, 0.01404492,
#        0.07720765, 0.01425675])

# %%
lr.intercept_
# Out:
# 0.7201176737522748

# %%
y = 0.0179352*x1 + 0.01586169*x2 +  0.00790237*x3 +  0.00148665*x4+ 0.01404492*x5+ 0.07720765*x6+ 0.01425675*x7 + 0.7201176737522748
